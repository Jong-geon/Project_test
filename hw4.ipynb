# %% [markdown]
# ## hw 4

# %%
def trap_rain_water(height):
    if not height:
        return 0

    n = len(height)
    left_max = [0] * n
    right_max = [0] * n

    left_max[0] = height[0]
    for i in range(1, n):
        left_max[i] = max(left_max[i-1], height[i])

    right_max[n-1] = height[n-1]
    for i in range(n-2, -1, -1):
        right_max[i] = max(right_max[i+1], height[i])

    trapped = 0
    for i in range(n):
        trapped += min(left_max[i], right_max[i]) - height[i]

    return trapped

import matplotlib.pyplot as plt

def plot_trap_water(height):
    n = len(height)
    left_max = [0]*n
    right_max = [0]*n

    left_max[0] = height[0]
    for i in range(1, n):
        left_max[i] = max(left_max[i-1], height[i])

    right_max[-1] = height[-1]
    for i in range(n-2, -1, -1):
        right_max[i] = max(right_max[i+1], height[i])

    water = [min(left_max[i], right_max[i]) - height[i] for i in range(n)]

    plt.bar(range(n), height, color='black', label='Ground')
    plt.bar(range(n), water, bottom=height, color='blue', alpha=0.5, label='Water')
    plt.title(f"Trapping Rain Water\nHeight = {height}\nTrapped Water = {sum(water)}")
    plt.xlabel("Index")
    plt.ylabel("Height")
    plt.ylim(0, max(height) + 1)
    plt.legend()
    plt.show()

# %%
# ex1
heights = [0,1,0,2,1,0,1,3,2,1,2,1]
print(trap_rain_water(heights))
plot_trap_water(heights)
# Out:
# 6

# %%
# ex2
heights = [0,3,2,4,1,5,1,3,6,1,5,3]
print(trap_rain_water(heights))
plot_trap_water(heights)
# Out:
# 14

# %%
# ex3
heights = [2,1,6,1,1,1,2,4,5,1,2,1]
print(trap_rain_water(heights))
plot_trap_water(heights)
# Out:
# 18
